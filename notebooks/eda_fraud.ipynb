# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.eda import FraudDetectionPipeline

# %%
pipeline = FraudDetectionPipeline("../data/raw/Fraud_Data.csv", "../data/raw/IpAddress_to_Country.csv")
X_train, y_train, X_test, y_test = pipeline.run()
# Out:
# 2026-06-11 12:41:40,788 - INFO - Fraud data loaded: (151112, 11)
# 2026-06-11 12:41:40,984 - INFO - IP-to-Country data loaded: (138846, 3)
# 2026-06-11 12:41:41,257 - INFO - Geolocation integration completed.
# ==========================================================================================
#  FULL EDA for Fraud Dataset
# ==========================================================================================
# Dataset Shape: (151112, 12)
#
# Data Types:
# user_id           int64
# signup_time         str
# purchase_time       str
# purchase_value    int64
# device_id           str
# source              str
# browser             str
# sex                 str
# age               int64
# ip_address        int64
# class             int64
# country             str
# dtype: object
#
# Missing Values Summary:
# Series([], dtype: int64)
#
# ================================================================================
# Numerical Features Summary
#                    count          mean           std      min           25%  \
# user_id         151112.0  2.001710e+05  1.153693e+05      2.0  1.006425e+05
# purchase_value  151112.0  3.693537e+01  1.832276e+01      9.0  2.200000e+01
# age             151112.0  3.314070e+01  8.617733e+00     18.0  2.700000e+01
# ip_address      151112.0  2.152145e+09  1.248497e+09  52093.0  1.085934e+09
# class           151112.0  9.364577e-02  2.913362e-01      0.0  0.000000e+00
#
#                          50%           75%           max
# user_id         1.999580e+05  3.000540e+05  4.000000e+05
# purchase_value  3.500000e+01  4.900000e+01  1.540000e+02
# age             3.300000e+01  3.900000e+01  7.600000e+01
# ip_address      2.154770e+09  3.243258e+09  4.294850e+09
# class           0.000000e+00  0.000000e+00  1.000000e+00
#
# Categorical / Object Features Summary
#                 count  unique                  top   freq
# signup_time    151112  151112  2015-02-16 00:17:05      1
# purchase_time  151112  150679  2015-09-10 09:04:53      3
# device_id      151112  137956        CQTUVBYIWWWBC     20
# source         151112       3                  SEO  60615
# browser        151112       5               Chrome  61432
# sex            151112       2                    M  88293
# country        151112     182        United States  58049
#
# Bivariate Analysis vs Target:
#
# user_id vs class:
#           count           mean            std   min       25%       50%  \
# class
# 0      136961.0  200098.920123  115239.994370   2.0  100789.0  199909.0
# 1       14151.0  200869.065366  116615.028662  39.0   98314.0  200526.0
#
#             75%       max
# class
# 0      299724.0  399997.0
# 1      303018.0  400000.0
# ----------------------------------------------------------------------
#
# purchase_value vs class:
#           count       mean        std  min   25%   50%   75%    max
# class
# 0      136961.0  36.929418  18.315064  9.0  22.0  35.0  49.0  154.0
# 1       14151.0  36.993004  18.397654  9.0  22.0  35.0  49.0  111.0
# ----------------------------------------------------------------------
#
# age vs class:
#           count       mean       std   min   25%   50%   75%   max
# class
# 0      136961.0  33.122356  8.622678  18.0  27.0  33.0  39.0  76.0
# 1       14151.0  33.318281  8.568001  18.0  27.0  33.0  39.0  68.0
# ----------------------------------------------------------------------
#
# ip_address vs class:
#           count          mean           std        min           25%  \
# class
# 0      136961.0  2.154235e+09  1.250927e+09    52093.0  1.084381e+09
# 1       14151.0  2.131918e+09  1.224590e+09  2278095.0  1.107616e+09
#
#                 50%           75%           max
# class
# 0      2.155916e+09  3.249408e+09  4.294850e+09
# 1      2.141692e+09  3.184225e+09  4.294131e+09
# ----------------------------------------------------------------------
#
# Target Imbalance:
# class
# 0    90.635423
# 1     9.364577
# Name: proportion, dtype: float64
# [Business Risk] High imbalance → risk of missing fraud events (revenue loss).
#
# ================================================================================
# Multivariate / Correlation Analysis
# Top Correlations with Target:
# class             1.000000
# age               0.006624
# ip_address       -0.005208
# user_id           0.001945
# purchase_value    0.001011
# Name: class, dtype: float64
# ================================================================================
# 2026-06-11 12:41:44,839 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# c:\Users\Hello\Desktop\kaim\fraud-detection\src\eda.py:280: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=col, data=df, palette='Set2')
# 2026-06-11 12:41:45,084 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:41:46,226 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# c:\Users\Hello\Desktop\kaim\fraud-detection\src\eda.py:280: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=col, data=df, palette='Set2')
# 2026-06-11 12:41:46,677 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:41:47,807 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# c:\Users\Hello\Desktop\kaim\fraud-detection\src\eda.py:280: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=col, data=df, palette='Set2')
# 2026-06-11 12:41:48,131 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:41:49,368 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# c:\Users\Hello\Desktop\kaim\fraud-detection\src\eda.py:280: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=target, y=col, data=df, palette='Set2')
# 2026-06-11 12:41:49,718 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ================================================================================
# Fraud Analysis by Country
# Top 10 Countries by Fraud Cases:
#                    total_transactions  fraud_cases  fraud_rate
# country
# United States                   58049         5551    0.095626
# Unknown                         21966         1883    0.085723
# China                           12038         1043    0.086642
# Japan                            7306          715    0.097865
# United Kingdom                   4490          477    0.106236
# Korea Republic of                4162          380    0.091302
# Canada                           2975          348    0.116975
# France                           3161          300    0.094907
# Brazil                           2961          270    0.091185
# Germany                          3646          262    0.071860
# c:\Users\Hello\Desktop\kaim\fraud-detection\src\eda.py:321: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=significant.index[:15], y=significant['fraud_rate'][:15], palette='Reds_r')
# c:\Users\Hello\Desktop\kaim\fraud-detection\src\eda.py:332: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_fraud_countries.index, y=top_fraud_countries['fraud_cases'], palette='Oranges_r')
# 2026-06-11 12:42:12,544 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:42:12,775 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:42:14,491 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:42:14,691 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:42:17,613 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:42:17,810 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-06-11 12:42:26,022 - INFO - Starting data cleaning...
# ================================================================================
# Missing Values Percentage:
#  Series([], dtype: float64)
# ================================================================================
# ================================================================================
# Duplicate Rows: 0.00%
# ================================================================================
# 2026-06-11 12:42:27,899 - INFO - Converted signup_time to datetime
# 2026-06-11 12:42:28,313 - INFO - Converted purchase_time to datetime
# ================================================================================
# Data Info after cleaning:
# <class 'pandas.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  datetime64[us]
#  2   purchase_time   151112 non-null  datetime64[us]
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  str
#  5   source          151112 non-null  category
#  6   browser         151112 non-null  category
#  7   sex             151112 non-null  category
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  int64
#  10  class           151112 non-null  int64
#  11  country         151112 non-null  str
# dtypes: category(3), datetime64[us](2), int64(5), str(2)
# memory usage: 10.8 MB
# ================================================================================
# Training shape before SMOTE: (120889, 197)
# Resampled Training Shape after SMOTE: (219136, 197)

# %% [markdown]
# ## Class imbalance handling - SMOTE
#
# The dataset is highly imbalanced, with fraudulent transactions representing a small
# minority of the data. Training a model on imbalanced data causes it to be biased
# toward the majority class (non-fraud), resulting in high accuracy but poor recall
# on the fraud class which is the class that matters most.
#
# SMOTE (Synthetic Minority Oversampling Technique) was chosen over random undersampling
# because undersampling discards legitimate majority-class examples, which wastes
# information. SMOTE instead generates synthetic minority-class samples by interpolating
# between existing fraud examples, preserving all majority-class data while balancing
# the distribution.
#
# Critically, SMOTE is applied **to the training set only** after the train/test split.
# Applying it before splitting would cause data leakage synthetic samples derived from
# the test set would bleed into training, artificially inflating model performance metrics.

# %%
from src.model_train import ModelTrain

# %%
mt=ModelTrain(X_train, y_train, X_test, y_test)
mt.train_log_reg(n_iter=5000)
# Out:
# The AUC ROC score:  0.7401055491337384
# The Average Precision Score:  0.354802512756615
# The F1 Score is  0.27674272555997487
# The confusion Matrix  [[17875  9518]
#  [  847  1983]]
# THe True Negative: 17875
#  The False Postives: 9518
#  The False Negatives: 847
#  The true Positives: 1983
#               precision    recall  f1-score   support
#
#    Not Fraud       0.95      0.65      0.78     27393
#        Fraud       0.17      0.70      0.28      2830
#
#     accuracy                           0.66     30223
#    macro avg       0.56      0.68      0.53     30223
# weighted avg       0.88      0.66      0.73     30223

# %%
'class' in X_train.columns
# Out:
# False

# %%
# mt.train_and_evaluate_models()
